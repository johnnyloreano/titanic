# %% [markdown]
# # Importing global packages

# %%
# %matplotlib inline

import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as ply
import seaborn as sns
# Just to hide cells....
from IPython.display import HTML
import warnings
import random

# %%
pd.set_option('display.max_rows', 500)
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

sns.set(rc={'figure.figsize':(11.7,8.27)})
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""");

# %%
def hide_toggle(for_next=False):
    this_cell = """$('div.cell.code_cell.rendered.selected')"""
    next_cell = this_cell + '.next()'

    toggle_text = 'Toggle show/hide'  # text shown on toggle link
    target_cell = this_cell  # target cell to control with toggle
    js_hide_current = ''  # bit of JS to permanently hide code in current cell (only when toggling next cell)

    if for_next:
        target_cell = next_cell
        toggle_text += ' next cell'
        js_hide_current = this_cell + '.find("div.input").hide();'

    js_f_name = 'code_toggle_{}'.format(str(random.randint(1,2**64)))

    html = """
        <script>
            function {f_name}() {{
                {cell_selector}.find('div.input').toggle();
            }}

            {js_hide_current}
        </script>

        <a href="javascript:{f_name}()">{toggle_text}</a>
    """.format(
        f_name=js_f_name,
        cell_selector=target_cell,
        js_hide_current=js_hide_current, 
        toggle_text=toggle_text
    )

    return HTML(html)

hide_toggle()
# Out:
#         <script>
#             function code_toggle_4029162616570037097() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_4029162616570037097()">Toggle show/hide</a>

# %%
dataset = pd.read_csv('./train.csv')

# %%
dataset.dtypes
print(dataset.shape)
# Out:
# (891, 12)

# %% [markdown]
# ## Check for null values

# %%
for column in dataset.columns:
    print(str(column) + "\t->\t" +  str(dataset[column].isnull().sum()))
# Out:
# PassengerId	->	0
# Survived	->	0
# Pclass	->	0
# Name	->	0
# Sex	->	0
# Age	->	177
# SibSp	->	0
# Parch	->	0
# Ticket	->	0
# Fare	->	0
# Cabin	->	687
# Embarked	->	2

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataset.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ## Useful functions

# %%
def survived_bar(feature):
    survived = dataset[dataset['Survived'] == 1][feature].value_counts()
    dead = dataset[dataset['Survived'] == 0][feature].value_counts()
    return pd.DataFrame([dead,survived], index = ["Dead", "Survived"])
hide_toggle()
# Out:
#         <script>
#             function code_toggle_4116029070026262051() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_4116029070026262051()">Toggle show/hide</a>

# %% [markdown]
# ## Useful groups

# %%
male = dataset[dataset['Sex'] == 'male']
female = dataset[dataset['Sex'] == 'female']

# %% [markdown]
# ## Name Attribute

# %% [markdown]
# ### Extract Surname

# %%
dataset['Name']

dataset['Surname'] = dataset.apply(lambda x : x['Name'].split(',')[0].strip(), axis = 1)

s = dataset.groupby(by = 'Surname').Surname.count()

s
# Out:
# Surname
# Abbing           1
# Abbott           2
# Abelson          2
# Adahl            1
# Adams            1
#                 ..
# de Mulder        1
# de Pelsmaeker    1
# del Carlo        1
# van Billiard     1
# van Melkebeke    1
# Name: Surname, Length: 667, dtype: int64

# %% [markdown]
# ### Extract Title Name

# %%
titles = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}

# extract titles
dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
# replace titles with a more common title or as Rare
dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr',\
                                            'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
# convert titles into numbers
dataset['Title'] = dataset['Title'].map(titles)
# filling NaN with 0, to get safe
dataset['Title'] = dataset['Title'].fillna(0)

# dataset[dataset['Title'].isnull()] -> EVERYONE HAS A TITLE!

# %%
survived_bar('Title').rename(columns= {1 : "Mr", 2 : "Miss" , 3 : "Mrs", 4 : "Master", 5 : "Rare"}).plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Sex attribute

# %% [markdown]
# Can be [male,female]

# %%
dataset['Sex'].value_counts().plot.pie( autopct='%1.0f%%', figsize = (5,5))
survived_bar('Sex').plot( kind = "pie", subplots=True, figsize = (10,10), autopct='%1.0f%%')
# Out:
# array([<AxesSubplot:ylabel='male'>, <AxesSubplot:ylabel='female'>],
#       dtype=object)

# %% [markdown]
# ## Age attribute
#
# Bin by age range ?

# %%
sns.violinplot(x='Sex', y='Age', 
               hue='Survived', data=dataset, 
               split=True,
               palette={0: "r", 1: "g"}
              );

# %%
dataset.groupby(by = 'Age').size().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
labels = [0,1,2,3,4,5,6]
dataset['Age_Group'] = pd.qcut(x = dataset['Age'], q = 7, labels = labels)

dataset['Age_Group'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
survived_bar('Age_Group').plot(kind = 'bar',figsize = (10,10), legend = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pclass - Ticket Class

# %% [markdown]
# Can be [1,2,3]. 1 is the most expensive, 3 is the most cheaper

# %%
dataset['Pclass'].value_counts().plot.pie( autopct='%1.0f%%', figsize = (5,5))
survived_bar('Pclass').transpose().plot( kind = "pie", subplots=True, figsize = (10,10), autopct='%1.0f%%')
# Out:
# array([<AxesSubplot:ylabel='Dead'>, <AxesSubplot:ylabel='Survived'>],
#       dtype=object)

# %% [markdown]
# ## Fare attribute

# %% [markdown]
# How much each one paid for the fare

# %%
sns.boxplot(x = 'Pclass', y = 'Fare', data = dataset, showfliers = True)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(x = 'Pclass', y = 'Fare', data = dataset, showfliers = False)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ## Analysis of Fares in outlier
#
# Fare with outlier

# %%
from matplotlib.cbook import boxplot_stats  
outl = boxplot_stats(dataset.Fare).pop(0)['fliers']

outlier_data = dataset[(dataset['Fare'].isin(outl)) & (dataset['Pclass'] == 1)]

normal_data = dataset[(dataset['Fare'].isin(outl) == False) & (dataset['Pclass'] == 1)]

(outlier_data['Survived'].value_counts()).plot(kind = 'pie', autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='Survived'>

# %% [markdown]
# Fare without outlier

# %%
(normal_data['Survived'].value_counts()).plot(kind = 'pie', autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
fig, ax = ply.subplots(figsize=(20,20))
sns.violinplot(ax=ax,x='Sex', y='Fare', 
               hue='Survived', data=dataset, 
               split=True,
               palette={0: "r", 1: "g"}
              );

# %% [markdown]
# ## Cabin Attribute
#
# #ON HOLD

# %%
# dataset[dataset['Cabin'].isnull() == False]['Cabin']

# %%
# dataset.loc[763]

# %% [markdown]
# ## Embarked attribute

# %%
dataset['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
survived_bar('Embarked').plot(kind = 'bar', figsize = (20,10), stacked = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Embarked & Class & Sex attribute

# %%
FacetGrid = sns.FacetGrid(dataset, row='Embarked', size=4.5, aspect=1.6)
FacetGrid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette=None,  order=None, hue_order=None )
FacetGrid.add_legend()

# %%
FacetGrid = sns.FacetGrid(dataset, row='Age_Group', size=4.5, aspect=1.6)
FacetGrid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette=None,  order=None, hue_order=None )
FacetGrid.add_legend()

# %%
grid = sns.FacetGrid(dataset[dataset['Sex'] == 'female'], col='Survived', row='Pclass', size=2.2, aspect=1.6)
grid.map(ply.hist, 'Age', alpha=.5, bins=20)
grid.add_legend();

# %% [markdown]
# ## Sibsp & Parch attributes

# %%
dataset['total_relatives'] = dataset.apply(lambda x: x['SibSp'] + x['Parch'], axis=1)
dataset['has_relative'] = dataset.apply(lambda x: int(bool(x['SibSp'] + x['Parch'])), axis=1)

# %% [markdown]
# ## Fixing empty values

# %%
print(str(len(no_age_dataset)) + ' missing values')
# Out:
# 177 missing values

# %% [markdown]
# ### Age

# %% [markdown]
# #### How is this data distributed ?

# %%
no_age_dataset = dataset[dataset['Age'].isnull()]
print(str(len(no_age_dataset)))
# Out:
# 14

# %%
no_age_dataset[['Sex']].value_counts()
# Out:
# Sex
# male      83
# female    13
# dtype: int64

# %%
no_age_dataset[['Pclass']].value_counts()
# Out:
# Pclass
# 3         71
# 1         15
# 2         10
# dtype: int64

# %%
no_age_dataset[['Title']].value_counts()
# Out:
# Title
# 1        82
# 3        11
# 2         2
# 5         1
# dtype: int64

# %%
no_age_dataset[no_age_dataset['Title'] == 5]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex  Age  \
# 766          767         0       1  Brewe, Dr. Arthur Jackson  male  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked Surname  Title  \
# 766      0      0  112379  39.6   NaN        C   Brewe      5
#
#      total_relatives  has_relative
# 766                0             0

# %%
dataset[
    dataset['Title'] == 5 &  (dataset['Survived'] == 0) & (dataset['Sex'] == 'male')].describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   436.000000     436.0  436.000000  357.000000  436.000000  436.000000
# mean    452.350917       0.0    2.488532   29.176471    0.300459    0.160550
# std     256.432937       0.0    0.756493   11.358111    0.873150    0.556594
# min       1.000000       0.0    1.000000   14.000000    0.000000    0.000000
# 25%     221.500000       0.0    2.000000   21.000000    0.000000    0.000000
# 50%     464.500000       0.0    3.000000   26.000000    0.000000    0.000000
# 75%     675.250000       0.0    3.000000   34.000000    0.000000    0.000000
# max     891.000000       0.0    3.000000   74.000000    8.000000    5.000000
#
#              Fare  Title  total_relatives  has_relative
# count  436.000000  436.0       436.000000    436.000000
# mean    21.218193    1.0         0.461009      0.229358
# std     33.085692    0.0         1.224592      0.420903
# ...

# %% [markdown]
# #### Filling the empty ages

# %% [markdown]
# I'll be using the STANDARD DEVIATION criteria to choose between certains conditions

# %% [markdown]
# ##### Females from Queenstown (49 rows,  27 % of missing values)

# %% [markdown]
# By my studies, this was one of smallest STANDARD DEVIATION (8.15). Therefore, I'm starting to fullfill the age by this criteria

# %%
dataset[dataset['Sex'] == 'female'].groupby( by = ['Embarked']).describe()['Age']
# Out:
#           count       mean        std    min   25%   50%     75%   max
# Embarked
# C          61.0  28.344262  15.770830   0.75  17.0  24.0  40.000  60.0
# Q          12.0  24.291667   8.147667  15.00  17.5  21.5  30.875  39.0
# S         186.0  27.771505  13.690703   1.00  19.0  27.0  36.000  63.0

# %%
print( 'Womans from Queenstown : ' + str(len(no_age_dataset[no_age_dataset['Embarked'] == 'Q'])))
print( 'Median of womans from Queenstown : ' + str(dataset[(dataset['Sex'] == 'female') & (dataset['Embarked'] == 'Q')]['Age'].median().astype(int)))
# Out:
# Womans from Queenstown : 49
# Median of womans from Queenstown : 21

# %%
dataset.loc[(dataset['Age'].isnull()) & (dataset['Sex'] == 'female') & (dataset['Embarked'] == 'Q'), 'Age' ] = dataset[(dataset['Sex'] == 'female') & (dataset['Embarked'] == 'Q')]['Age'].median().astype(int)

# %% [markdown]
# ##### Pclass 3, Title 2 | 4 (15 rows,  8.5 % of missing values)

# %%
print( 'Pclass 3, Title 2 OR 4 : ' + str(len(no_age_dataset[(no_age_dataset['Pclass'] == 3) & (no_age_dataset['Title'] == 2) | (no_age_dataset['Title'] == 4) ])))
print( 'Median of PCLASS 3 and title 2 : ' + str(dataset[(dataset['Pclass'] == 3) & (dataset['Title'] == 2) ]['Age'].median()))

print( 'Median of PCLASS 3 and title 4 : ' + str(dataset[(dataset['Pclass'] == 3) & (dataset['Title'] == 4)]['Age'].median()))
# Out:
# Pclass 3, Title 2 OR 4 : 15
# Median of PCLASS 3 and title 2 : 21.0
# Median of PCLASS 3 and title 4 : 4.0

# %%
dataset.loc[(dataset['Age'].isnull()) & (dataset['Pclass'] == 3) & (dataset['Title'] == 2), 'Age' ] = dataset[(dataset['Pclass'] == 3) & (dataset['Title'] == 2)]['Age'].median().astype(int)


dataset.loc[(dataset['Age'].isnull()) & (dataset['Pclass'] == 3) & (dataset['Title'] == 4), 'Age' ] = dataset[(dataset['Pclass'] == 3) & (dataset['Title'] == 4)]['Age'].median().astype(int)

# %% [markdown]
# ##### Males, Title 1 from ShoutHampton & C (30 rows, )

# %%
print( 'Males, Title 1 : ' + str(len(no_age_dataset[(no_age_dataset['Sex'] == 'male') &  (no_age_dataset['Title'] == 1)])))

print( 'Median of Males, title 1 From S : ' + str(dataset[(dataset['Sex'] == 'male') & (dataset['Title'] == 1) & (dataset['Embarked'] == 'S') & (dataset['Pclass'] == 1)]['Age'].median().astype(int)))
print( 'Median of Males, title 1 From C : ' + str(dataset[(dataset['Sex'] == 'male') & (dataset['Title'] == 1) & (dataset['Embarked'] == 'C') & (dataset['Pclass'] == 3)]['Age'].median().astype(int)))
# Out:
# Males, Title 1 : 119
# Median of Males, title 1 From S : 42
# Median of Males, title 1 From C : 26

# %%
dataset.loc[(dataset['Sex'] == 'male') & (dataset['Title'] == 1) & (dataset['Embarked'] == 'S') & (dataset['Pclass'] == 1),'Age'] = dataset[(dataset['Sex'] == 'male') & (dataset['Title'] == 1) & (dataset['Embarked'] == 'S') & (dataset['Pclass'] == 1)]['Age'].median().astype(int)

dataset.loc[(dataset['Age'].isnull()) & 
    (dataset['Sex'] == 'male') & 
            (dataset['Title'] == 1) &
            (dataset['Embarked'] == 'C') & 
            (dataset['Pclass'] == 3),'Age'] = dataset[(dataset['Sex'] == 'male') & (dataset['Title'] == 1) & (dataset['Embarked'] == 'C') & (dataset['Pclass'] == 3)]['Age'].median().astype(int)

# %% [markdown]
# ##### People who survived,  Pclass is 3 (11 rows,  6 %)

# %%
print( 'People who survived,  Pclass is 3 : ' + 
      str(
          len(
              no_age_dataset[(no_age_dataset['Pclass'] == 3) 
                             & 
                             (no_age_dataset['Survived'] == 1)
                            ]
          )
      )
     )
print( 'Median of People who survived,  Pclass is 3 : '
      + 
      str(dataset[(dataset['Pclass'] == 3 ) & 
                  (dataset['Survived'] == 1) ]['Age'].median().astype(int)))
# Out:
# People who survived,  Pclass is 3 : 11
# Median of People who survived,  Pclass is 3 : 21

# %%
dataset.loc[ (dataset['Age'].isnull()) & 
    (dataset['Pclass'] == 3) & (dataset['Survived'] == 1) 
    ,'Age'] = dataset[
                        (dataset['Pclass'] == 3 ) & 
                          (dataset['Survived'] == 1)
                            ]['Age'].median().astype(int)

# %% [markdown]
# ##### Unique with title = 5

# %%
dataset.loc[ (dataset['Age'].isnull()) & 
    dataset['Title'] == 5 &  (dataset['Survived'] == 0) & (dataset['Sex'] == 'male')] = dataset[
    dataset['Title'] == 5 &  (dataset['Survived'] == 0) & (dataset['Sex'] == 'male')]['Age'].median().astype(int)
