# %% [markdown]
# # Importing global packages

# %%
# %matplotlib inline

import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as ply
import seaborn as sns
# Just to hide cells....
from IPython.display import HTML
import warnings
import random

# %%
pd.set_option('display.max_rows', 500)
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

sns.set(rc={'figure.figsize':(11.7,8.27)})
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""");

# %%
def hide_toggle(for_next=False):
    this_cell = """$('div.cell.code_cell.rendered.selected')"""
    next_cell = this_cell + '.next()'

    toggle_text = 'Toggle show/hide'  # text shown on toggle link
    target_cell = this_cell  # target cell to control with toggle
    js_hide_current = ''  # bit of JS to permanently hide code in current cell (only when toggling next cell)

    if for_next:
        target_cell = next_cell
        toggle_text += ' next cell'
        js_hide_current = this_cell + '.find("div.input").hide();'

    js_f_name = 'code_toggle_{}'.format(str(random.randint(1,2**64)))

    html = """
        <script>
            function {f_name}() {{
                {cell_selector}.find('div.input').toggle();
            }}

            {js_hide_current}
        </script>

        <a href="javascript:{f_name}()">{toggle_text}</a>
    """.format(
        f_name=js_f_name,
        cell_selector=target_cell,
        js_hide_current=js_hide_current, 
        toggle_text=toggle_text
    )

    return HTML(html)

hide_toggle()
# Out:
#         <script>
#             function code_toggle_18403872446356051079() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_18403872446356051079()">Toggle show/hide</a>

# %%
dataset = pd.read_csv('./train.csv')

# %%
dataset.dtypes
print(dataset.shape)
# Out:
# (891, 12)

# %% [markdown]
# ## Check for null values

# %%
for column in dataset.columns:
    print(str(column) + "\t->\t" +  str(dataset[column].isnull().sum()))
# Out:
# PassengerId	->	0
# Survived	->	0
# Pclass	->	0
# Name	->	0
# Sex	->	0
# Age	->	177
# SibSp	->	0
# Parch	->	0
# Ticket	->	0
# Fare	->	0
# Cabin	->	687
# Embarked	->	2

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataset.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ## Useful functions

# %%
def survived_bar(feature):
    survived = dataset[dataset['Survived'] == 1][feature].value_counts()
    dead = dataset[dataset['Survived'] == 0][feature].value_counts()
    return pd.DataFrame([dead,survived], index = ["Dead", "Survived"])
hide_toggle()
# Out:
#         <script>
#             function code_toggle_13838849072917565598() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_13838849072917565598()">Toggle show/hide</a>

# %% [markdown]
# ## Useful groups

# %%
male = dataset[dataset['Sex'] == 'male']
female = dataset[dataset['Sex'] == 'female']

# %% [markdown]
# ## Name Attribute

# %% [markdown]
# ### Extract Surname

# %%
dataset['Name']

dataset['Surname'] = dataset.apply(lambda x : x['Name'].split(',')[0].strip(), axis = 1)

s = dataset.groupby(by = 'Surname').Surname.count()

s
# Out:
# Surname
# Abbing           1
# Abbott           2
# Abelson          2
# Adahl            1
# Adams            1
#                 ..
# de Mulder        1
# de Pelsmaeker    1
# del Carlo        1
# van Billiard     1
# van Melkebeke    1
# Name: Surname, Length: 667, dtype: int64

# %% [markdown]
# ### Extract Title Name

# %%
titles = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}

# extract titles
dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
# replace titles with a more common title or as Rare
dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr',\
                                            'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
# convert titles into numbers
dataset['Title'] = dataset['Title'].map(titles)
# filling NaN with 0, to get safe
dataset['Title'] = dataset['Title'].fillna(0)

# dataset[dataset['Title'].isnull()] -> EVERYONE HAS A TITLE!

# %%
survived_bar('Title').rename(columns= {1 : "Mr", 2 : "Miss" , 3 : "Mrs", 4 : "Master", 5 : "Rare"}).plot(kind = "bar")

# %% [markdown]
# ## Sex attribute

# %% [markdown]
# Can be [male,female]

# %%
dataset['Sex'].value_counts().plot.pie( autopct='%1.0f%%', figsize = (5,5))
survived_bar('Sex').plot( kind = "pie", subplots=True, figsize = (10,10), autopct='%1.0f%%')
# Out:
# array([<AxesSubplot:ylabel='male'>, <AxesSubplot:ylabel='female'>],
#       dtype=object)

# %% [markdown]
# ## Age attribute
#
# Bin by age range ?

# %%
sns.violinplot(x='Sex', y='Age', 
               hue='Survived', data=dataset, 
               split=True,
               palette={0: "r", 1: "g"}
              );

# %%
dataset.groupby(by = 'Age').size().plot(kind = 'bar')

# %%
labels = [0,1,2,3,4,5,6]
dataset['Age_Group'] = pd.qcut(x = dataset['Age'], q = 7, labels = labels)

dataset['Age_Group'].value_counts().plot(kind = 'bar')

# %%
survived_bar('Age_Group').transpose().plot(kind = 'pie', subplots = True, figsize = (10,10), autopct='%1.0f%%', legend = False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C47890308>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C477B4048>],
#       dtype=object)

# %% [markdown]
# ## Pclass - Ticket Class

# %% [markdown]
# Can be [1,2,3]. 1 is the most expensive, 3 is the most cheaper

# %%
dataset['Pclass'].value_counts().plot.pie( autopct='%1.0f%%', figsize = (5,5))
survived_bar('Pclass').transpose().plot( kind = "pie", subplots=True, figsize = (10,10), autopct='%1.0f%%')
# Out:
# array([<AxesSubplot:ylabel='Dead'>, <AxesSubplot:ylabel='Survived'>],
#       dtype=object)

# %% [markdown]
# ## Fare attribute

# %% [markdown]
# How much each one paid for the fare

# %%
sns.boxplot(x = 'Pclass', y = 'Fare', data = dataset, showfliers = True)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(x = 'Pclass', y = 'Fare', data = dataset, showfliers = False)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ## Analysis of Fares in outlier
#
# Fare with outlier

# %%
from matplotlib.cbook import boxplot_stats  
outl = boxplot_stats(dataset.Fare).pop(0)['fliers']

outlier_data = dataset[(dataset['Fare'].isin(outl)) & (dataset['Pclass'] == 1)]

normal_data = dataset[(dataset['Fare'].isin(outl) == False) & (dataset['Pclass'] == 1)]

(outlier_data['Survived'].value_counts()).plot(kind = 'pie', autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='Survived'>

# %% [markdown]
# Fare without outlier

# %%
(normal_data['Survived'].value_counts()).plot(kind = 'pie', autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
fig, ax = ply.subplots(figsize=(20,20))
sns.violinplot(ax=ax,x='Sex', y='Fare', 
               hue='Survived', data=dataset, 
               split=True,
               palette={0: "r", 1: "g"}
              );

# %% [markdown]
# ## Cabin Attribute
#
# #ON HOLD

# %%
# dataset[dataset['Cabin'].isnull() == False]['Cabin']

# %%
# dataset.loc[763]
# Out:
# PassengerId                                          764
# Survived                                               1
# Pclass                                                 1
# Name           Carter, Mrs. William Ernest (Lucile Polk)
# Sex                                               female
# Age                                                   36
# SibSp                                                  1
# Parch                                                  2
# Ticket                                            113760
# Fare                                                 120
# Cabin                                            B96 B98
# Embarked                                               S
# Name: 763, dtype: object

# %% [markdown]
# ## Embarked attribute

# %%
dataset['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
survived_bar('Embarked').plot(kind = 'bar', figsize = (20,10), stacked = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Embarked & Class & Sex attribute

# %%
FacetGrid = sns.FacetGrid(dataset, row='Embarked', size=4.5, aspect=1.6)
FacetGrid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette=None,  order=None, hue_order=None )
FacetGrid.add_legend()

# %%
FacetGrid = sns.FacetGrid(dataset, row='Age_Group', size=4.5, aspect=1.6)
FacetGrid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette=None,  order=None, hue_order=None )
FacetGrid.add_legend()

# %%
grid = sns.FacetGrid(dataset[dataset['Sex'] == 'female'], col='Survived', row='Pclass', size=2.2, aspect=1.6)
grid.map(ply.hist, 'Age', alpha=.5, bins=20)
grid.add_legend();

# %% [markdown]
# ## Sibsp & Parch attributes

# %%
dataset['total_relatives'] = dataset.apply(lambda x: x['SibSp'] + x['Parch'], axis=1)
dataset['has_relative'] = dataset.apply(lambda x: int(bool(x['SibSp'] + x['Parch'])), axis=1)

# %% [markdown]
# ## Fixing empty values

# %% [markdown]
# ### Age

# %% [markdown]
# #### How is this data distributed ?

# %%
no_age_dataset = dataset[dataset['Age'].isnull()]

# %%
no_age_dataset.groupby(['Sex','Pclass']).size()
# Out:
# Sex     Pclass
# female  1          9
#         2          2
#         3         42
# male    1         21
#         2          9
#         3         94
# dtype: int64

# %%
# dataset[(dataset['Age'].isnull()) & (dataset['Pclass'] == 3)]['Sex'].value_counts()

# %%
# dataset[(dataset['Age'].isnull()) & (dataset['Pclass'] == 3) &( dataset['Sex'] == 'female')]['Embarked'].value_counts()

# %%
# dataset[dataset['Age'].isnull()]['Sex'].value_counts()

# %%
# dataset[dataset['Age'].isnull()]['Title'].value_counts()

# %%
# dataset[dataset['Age'].isnull()]['Embarked'].value_counts()

# %%
# dataset[dataset['Age'].isnull()]['Survived'].value_counts()

# %%
# dataset[(dataset['Sex'] == 'female') & (dataset['Pclass'] == 3)]['Embarked'].value_counts()

# %%
dataset[(dataset['Sex'] == 'female') & (dataset['Pclass'] == 3) & (dataset['Embarked'] == '') ]['Age'].describe()
# Out:
# count    76.000000
# mean     23.223684
# std      12.963126
# min       1.000000
# 25%      16.750000
# 50%      23.000000
# 75%      30.250000
# max      63.000000
# Name: Age, dtype: float64

# %%
dataset[(dataset['Sex'] == 'female') & (dataset['Pclass'] == 3) & (dataset['Embarked'] == 'C') & (dataset['Title'] == 2)  ]['Age'].describe()
# Out:
# count    12.000000
# mean      9.333333
# std       6.688128
# min       0.750000
# 25%       3.250000
# 50%      11.000000
# 75%      14.625000
# max      18.000000
# Name: Age, dtype: float64

# %%
dataset[(dataset['Sex'] == 'female') & (dataset['Pclass'] == 3) & (dataset['Title'] == 2)]['Age'].describe()
# Out:
# count    69.000000
# mean     16.123188
# std       9.697315
# min       0.750000
# 25%       9.000000
# 50%      18.000000
# 75%      22.000000
# max      45.000000
# Name: Age, dtype: float64

# %%
dataset[(dataset['Sex'] == 'female') & (dataset['Pclass'] == 3) & (dataset['Title'] == 3)]['Age'].describe()
# Out:
# count    33.000000
# mean     33.515152
# std      10.031579
# min      15.000000
# 25%      27.000000
# 50%      31.000000
# 75%      40.000000
# max      63.000000
# Name: Age, dtype: float64

# %%
dataset[(dataset['Age'].isnull()) & (dataset['Pclass'] == 3)]['Sex'].value_counts()
# Out:
# male      94
# female    42
# Name: Sex, dtype: int64

# %%
dataset.groupby(by = 'Title')['Age'].describe()
# Out:
#        count       mean        std    min   25%   50%   75%   max
# Title
# 1      398.0  32.368090  12.708793  11.00  23.0  30.0  39.0  80.0
# 2      149.0  21.845638  12.870542   0.75  14.5  21.0  30.0  63.0
# 3      109.0  35.788991  11.437490  14.00  27.0  35.0  44.0  63.0
# 4       36.0   4.574167   3.619872   0.42   1.0   3.5   8.0  12.0
# 5       22.0  45.545455  11.782664  23.00  38.5  48.5  53.5  70.0

# %%
dataset[dataset['Pclass'] == 3].groupby(by = ['Title'])['Age'].describe()
# Out:
#        count       mean        std    min   25%   50%   75%   max
# Title
# 1      229.0  28.724891  10.490946  11.00  21.0  26.0  34.0  74.0
# 2       69.0  16.123188   9.697315   0.75   9.0  18.0  22.0  45.0
# 3       33.0  33.515152  10.031579  15.00  27.0  31.0  40.0  63.0
# 4       24.0   5.350833   3.593608   0.42   2.0   4.0   9.0  12.0

# %%
dataset.groupby(by = 'Pclass')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Pclass
# 1       186.0  38.233441  14.802856  0.92  27.0  37.0  49.0  80.0
# 2       173.0  29.877630  14.001077  0.67  23.0  29.0  36.0  70.0
# 3       355.0  25.140620  12.495398  0.42  18.0  24.0  32.0  74.0

# %%
dataset.groupby('Title')['Age'].median()
# Out:
# Title
# 1    30.0
# 2    21.0
# 3    35.0
# 4     3.5
# 5    48.5
# Name: Age, dtype: float64

# %% [markdown]
# ## Features Enginnering

# %% [markdown]
# ### Age Range

# %%
dataset['Age_Group'] = dataset.apply(lambda x: x['Age'] / 16, axis = 1)

# %%
dataset['Age_Group']
# Out:
# 0      1.3750
# 1      2.3750
# 2      1.6250
# 3      2.1875
# 4      2.1875
#         ...
# 886    1.6875
# 887    1.1875
# 888       NaN
# 889    1.6250
# 890    2.0000
# Name: Age_Group, Length: 891, dtype: float64
